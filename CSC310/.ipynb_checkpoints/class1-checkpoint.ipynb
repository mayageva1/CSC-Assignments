# %% [markdown]
# # Intro to Jupyter Notebooks

# %%
3+4
# Out:
# 7

# %%
name = "Maya"

# %%
name
# Out:
# 'Maya'

# %%
name_list = ["Sarah", "Adam", "Alex"]

# %%
name_list
# Out:
# ['Sarah', 'Adam', 'Alex']

# %%
print(name_list)
# Out:
# ['Sarah', 'Adam', 'Alex']

# %%
year = '2027'

# %%
print(name,year)
# Out:
# Maya 2027

# %%
print(name,year,sep='\n')
# Out:
# Maya
# 2027
