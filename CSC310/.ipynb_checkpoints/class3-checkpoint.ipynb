# %% [markdown]
# Pandas Data Frames

# %%
import pandas as pd

# %%
import coffee

# %%
coffee.robusta_data_url
# Out:
# 'https://raw.githubusercontent.com/jldbc/coffee-quality-database/master/data/robusta_data_cleaned.csv'

# %%
from coffee import robusta_data_url

# %%
coffee_df = pd.read_csv(robusta_data_url)

# %%
type(coffee_df)
# Out:
# pandas.core.frame.DataFrame

# %%
coffee_df.head()
# Out:
#    Unnamed: 0  Species                         Owner Country.of.Origin  \
# 0           1  Robusta  ankole coffee producers coop            Uganda
# 1           2  Robusta                nishant gurjer             India
# 2           3  Robusta                 andrew hetzel             India
# 3           4  Robusta                        ugacof            Uganda
# 4           5  Robusta  katuka development trust ltd            Uganda
#
#                             Farm.Name Lot.Number                      Mill  \
# 0       kyangundu cooperative society        NaN   ankole coffee producers
# 1      sethuraman estate kaapi royale         25         sethuraman estate
# 2                   sethuraman estate        NaN                       NaN
# 3                 ugacof project area        NaN                    ugacof
# 4  katikamu capca farmers association        NaN  katuka development trust
#
#         ICO.Number                       Company   Altitude  ...  Color  \
# ...

# %%
coffee_df.tail(3)
# Out:
#     Unnamed: 0  Species          Owner Country.of.Origin        Farm.Name  \
# 25          26  Robusta    james moore     United States  fazenda cazengo
# 26          27  Robusta  cafe politico             India              NaN
# 27          28  Robusta  cafe politico           Vietnam              NaN
#
#    Lot.Number          Mill         ICO.Number                  Company  \
# 25        NaN  cafe cazengo                NaN  global opportunity fund
# 26        NaN           NaN  14-1118-2014-0087            cafe politico
# 27        NaN           NaN                NaN            cafe politico
#
#       Altitude  ...  Color Category.Two.Defects           Expiration  \
# 25  795 meters  ...    NaN                    6  December 23rd, 2015
# 26         NaN  ...  Green                    1    August 25th, 2015
# 27         NaN  ...    NaN                    9    August 25th, 2015
#
#               Certification.Body                     Certification.Address  \
# ...

# %%
coffee_df = pd.read_csv(robusta_data_url,)

# %%
coffee_df.columns
# Out:
# Index(['Unnamed: 0', 'Species', 'Owner', 'Country.of.Origin', 'Farm.Name',
#        'Lot.Number', 'Mill', 'ICO.Number', 'Company', 'Altitude', 'Region',
#        'Producer', 'Number.of.Bags', 'Bag.Weight', 'In.Country.Partner',
#        'Harvest.Year', 'Grading.Date', 'Owner.1', 'Variety',
#        'Processing.Method', 'Fragrance...Aroma', 'Flavor', 'Aftertaste',
#        'Salt...Acid', 'Bitter...Sweet', 'Mouthfeel', 'Uniform.Cup',
#        'Clean.Cup', 'Balance', 'Cupper.Points', 'Total.Cup.Points', 'Moisture',
#        'Category.One.Defects', 'Quakers', 'Color', 'Category.Two.Defects',
#        'Expiration', 'Certification.Body', 'Certification.Address',
#        'Certification.Contact', 'unit_of_measurement', 'altitude_low_meters',
#        'altitude_high_meters', 'altitude_mean_meters'],
#       dtype='object')

# %%
coffee_df.index
# Out:
# RangeIndex(start=0, stop=28, step=1)

# %%
coffee_df.values
# Out:
# array([[1, 'Robusta', 'ankole coffee producers coop', ..., 1488.0,
#         1488.0, 1488.0],
#        [2, 'Robusta', 'nishant gurjer', ..., 3170.0, 3170.0, 3170.0],
#        [3, 'Robusta', 'andrew hetzel', ..., 1000.0, 1000.0, 1000.0],
#        ...,
#        [26, 'Robusta', 'james moore', ..., 795.0, 795.0, 795.0],
#        [27, 'Robusta', 'cafe politico', ..., nan, nan, nan],
#        [28, 'Robusta', 'cafe politico', ..., nan, nan, nan]], dtype=object)

# %%
high_flavor = coffee_df['Flavor']>7.8
coffee_df[high_flavor]
# Out:
#     Unnamed: 0  Species                         Owner Country.of.Origin  \
# 0            1  Robusta  ankole coffee producers coop            Uganda
# 2            3  Robusta                 andrew hetzel             India
# 3            4  Robusta                        ugacof            Uganda
# 4            5  Robusta  katuka development trust ltd            Uganda
# 5            6  Robusta                 andrew hetzel             India
# 9           10  Robusta                        ugacof            Uganda
# 10          11  Robusta                        ugacof            Uganda
# 11          12  Robusta                nishant gurjer             India
#
#                              Farm.Name Lot.Number                      Mill  \
# 0        kyangundu cooperative society        NaN   ankole coffee producers
# 2                    sethuraman estate        NaN                       NaN
# 3                  ugacof project area        NaN                    ugacof
# ...

# %%
coffee_vals = coffee_df.values

# %%
coffee_vals.shape
# Out:
# (28, 44)

# %%
coffee_df.shape
# Out:
# (28, 44)

# %% [markdown]
# reading from a website

# %%
coffee.achievements_url
# Out:
# 'https://rhodyprog4ds.github.io/BrownFall24/syllabus/achievements.html'

# %%
ach_df_list = pd.read_html(achievements_url,)
ach_defn = ach_df_list[2]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 ach_df_list = pd.read_html(achievements_url,)
#       2 ach_defn = ach_df_list[2]
#
# NameError: name 'achievements_url' is not defined

# %%
small_batch = ach_df_list['Number.of.Bags']<100
small_batch_df = coffee_df[small_batch]

# %%
small_batch.to_csv('robusta_small_batch.csv')
